# %%
'''
simple script to examine the contents of the database, dev.duckdb.
'''

import duckdb

con = duckdb.connect("../dev.duckdb")

print(con.sql("SHOW TABLES"))

con.close()
# Out:
# ┌───────────────────────┐
# │         name          │
# │        varchar        │
# ├───────────────────────┤
# │ fct_monthly_revenue   │
# │ fct_wallet_activation │
# │ giftcard_sales        │
# │ int_transactions      │
# │ int_wallet_activation │
# │ raw_merchants         │
# │ raw_transactions      │
# │ raw_wallets           │
# │ stg_merchants         │
# │ stg_transactions      │
# │ stg_wallets           │
# └───────────────────────┘
#          11 rows
